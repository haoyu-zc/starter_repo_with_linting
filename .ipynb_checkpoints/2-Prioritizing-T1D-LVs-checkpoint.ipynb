# %% [markdown]
# # Analysis 1
#
# - *Isolate 17 LVs associate to T1D related traits*
# - What are these LVs telling us
# - *Look at 17 LVs are expressed in RNAseq from Whole blood*
# - Compute 17 daisy anova using LVs from UKbiobank and emerge
# - What are these LVs telling us in three group
# - Look at signatures from the three groups within LVs of interest
# - look at the boxplot for top 17 LVs (UK biobank)

# %% [markdown]
# ## load packages

# %%
library(tidyverse, warn.conflicts=FALSE)
library("ggpubr")
library(reticulate)
library(jsonlite)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten

# %% [markdown]
# ## chose time point

# %%
tp <- "diff"
#tp <- "1"
#tp <- "2"

# %% [markdown]
# ## Importing data: UKBiobank and emerge LV, phenotype traits strings, RNA projection data

# %%
# Import data
gls_phenomexcan <- readRDS("data/input/gls-summary-phenomexcan.rds")
gls_emerge <- readRDS("data/input/gls-summary-emerge.rds")

# Type 1 diabetes traits in dataset 
UK_biobank_traits <-  c('Type 1 diabetes with ketoacidosis','Type 1 diabetes', 'Non-cancer illness code, self-reported: type 1 diabetes', 'Type 1 diabetes without complications','Type 1 diabetes with ophthalmic complications')
emerge_trait <- 'Type 1 diabetes'

# Daisy RNAseq projection
DAISY_diff_proj <- readRDS(paste0("output/gp_RNA_proj_",tp,".rds"))

# %% [markdown]
# ## 17 LVs associated with T1D in phenomexcan and emerge at p-value <0.01 (p value is in -log10)

# %%
#987 LVs in both cohort, narrow down to phenotypes related to T1D
phe_T1D_LVs <- gls_phenomexcan[gls_phenomexcan$phenotype_desc %in% UK_biobank_traits,]
e_T1D_LVs <- gls_emerge[gls_emerge$phenotype_desc %in% emerge_trait,]

# There are 17 LVs invovled in T1D from both phenomexcan and e-merge at a nominal p-value of 0.01
#122
phe_T1D_LVs_nom_0.01 <- phe_T1D_LVs[phe_T1D_LVs$pvalue < 0.01,]
colnames(phe_T1D_LVs_nom_0.01)
#dim(phe_T1D_LVs_nom_0.01)
#19
e_T1D_LVs_nom_0.01 <- e_T1D_LVs[e_T1D_LVs$pvalue < 0.01, ]
#17
phe_U_e_nom_0.01 <- inner_join(phe_T1D_LVs_nom_0.01,e_T1D_LVs_nom_0.01, by = "lv")
#phe_U_e_nom_0.01

grouped <- phe_U_e_nom_0.01%>%
arrange(lv)%>%
select(c(3,2,4,5,7,8,9))
colnames(grouped) <- c("LV","UK-Bio-Pheno", "UK-Bio-p-value","UK_Bio_fdr","emerge-pheno","emerge-p-value","emerge-fdr")
#print(grouped)
grouped
dim(grouped)
# Out:
# [1] "phenotype"      "phenotype_desc" "lv"             "pvalue"
# [5] "fdr"
#    LV    UK-Bio-Pheno                                            UK-Bio-p-value
# 1  LV109 Type 1 diabetes with ketoacidosis                       1.488463e-03
# 2  LV109 Type 1 diabetes                                         8.776640e-04
# 3  LV109 Non-cancer illness code, self-reported: type 1 diabetes 3.576582e-04
# 4  LV187 Type 1 diabetes                                         4.992971e-04
# 5  LV187 Non-cancer illness code, self-reported: type 1 diabetes 1.650055e-04
# 6  LV187 Type 1 diabetes with ophthalmic complications           7.020139e-03
# 7  LV205 Type 1 diabetes with ketoacidosis                       3.308170e-05
# 8  LV205 Type 1 diabetes                                         1.238614e-04
# 9  LV205 Non-cancer illness code, self-reported: type 1 diabetes 4.346665e-04
# 10 LV205 Type 1 diabetes without complications                   6.935551e-03
# 11 LV205 Type 1 diabetes with ophthalmic complications           6.796624e-03
# 12 LV293 Type 1 diabetes with ketoacidosis                       1.100424e-03
# 13 LV293 Type 1 diabetes                                         3.404989e-05
# 14 LV293 Non-cancer illness code, self-reported: type 1 diabetes 3.530829e-04
# 15 LV293 Type 1 diabetes without complications                   7.722357e-05
# 16 LV293 Type 1 diabetes with ophthalmic complications           1.395077e-03
# 17 LV342 Type 1 diabetes with ketoacidosis                       2.371331e-04
# 18 LV342 Type 1 diabetes                                         3.394141e-04
# 19 LV342 Non-cancer illness code, self-reported: type 1 diabetes 1.112260e-03
# 20 LV45  Type 1 diabetes with ketoacidosis                       8.689770e-05
# 21 LV45  Type 1 diabetes                                         1.889049e-05
# 22 LV45  Non-cancer illness code, self-reported: type 1 diabetes 1.225965e-06
# 23 LV45  Type 1 diabetes without complications                   1.516479e-05
# 24 LV45  Type 1 diabetes with ophthalmic complications           2.049586e-03
# 25 LV52  Type 1 diabetes                                         1.523154e-03
# 26 LV52  Non-cancer illness code, self-reported: type 1 diabetes 2.192244e-03
# 27 LV52  Type 1 diabetes without complications                   6.796215e-04
# 28 LV52  Type 1 diabetes with ophthalmic complications           4.145247e-03
# 29 LV54  Type 1 diabetes with ketoacidosis                       5.043826e-03
# 30 LV54  Type 1 diabetes                                         1.130128e-03
# 31 LV54  Non-cancer illness code, self-reported: type 1 diabetes 1.783437e-03
# 32 LV572 Type 1 diabetes with ketoacidosis                       7.776255e-04
# 33 LV572 Non-cancer illness code, self-reported: type 1 diabetes 7.322507e-03
# 34 LV625 Type 1 diabetes with ketoacidosis                       8.936994e-03
# 35 LV625 Type 1 diabetes                                         6.584334e-04
# 36 LV625 Non-cancer illness code, self-reported: type 1 diabetes 6.718596e-04
# 37 LV71  Type 1 diabetes with ketoacidosis                       5.915115e-05
# 38 LV71  Type 1 diabetes                                         2.190743e-03
# 39 LV71  Non-cancer illness code, self-reported: type 1 diabetes 6.006925e-03
# 40 LV71  Type 1 diabetes with ophthalmic complications           8.743835e-03
# 41 LV835 Type 1 diabetes                                         5.234704e-03
# 42 LV835 Type 1 diabetes without complications                   4.220133e-03
# 43 LV844 Type 1 diabetes with ketoacidosis                       2.245769e-08
# 44 LV844 Type 1 diabetes                                         5.817979e-06
# 45 LV844 Non-cancer illness code, self-reported: type 1 diabetes 9.318352e-09
# 46 LV844 Type 1 diabetes without complications                   3.438391e-07
# 47 LV861 Type 1 diabetes                                         1.895193e-03
# 48 LV861 Non-cancer illness code, self-reported: type 1 diabetes 3.200113e-04
# 49 LV861 Type 1 diabetes without complications                   2.146948e-03
# 50 LV906 Type 1 diabetes with ketoacidosis                       3.192363e-03
# 51 LV913 Type 1 diabetes with ketoacidosis                       7.235450e-06
# 52 LV913 Type 1 diabetes                                         6.869573e-06
# 38 3.873462e-01 Type 1 diabetes 8.541361e-05   0.084453886
# 39 5.452771e-01 Type 1 diabetes 8.541361e-05   0.084453886
# 40 6.089676e-01 Type 1 diabetes 8.541361e-05   0.084453886
# 41 5.215094e-01 Type 1 diabetes 8.382260e-04   0.280312151
# 42 4.865966e-01 Type 1 diabetes 8.382260e-04   0.280312151
# 43 1.030455e-04 Type 1 diabetes 1.462231e-03   0.356256946
# 44 1.044550e-02 Type 1 diabetes 1.462231e-03   0.356256946
# 45 4.705034e-05 Type 1 diabetes 1.462231e-03   0.356256946
# 46 1.054183e-03 Type 1 diabetes 1.462231e-03   0.356256946
# 47 3.666387e-01 Type 1 diabetes 4.018723e-04   0.196102756
# 48 1.597808e-01 Type 1 diabetes 4.018723e-04   0.196102756
# 49 3.839263e-01 Type 1 diabetes 4.018723e-04   0.196102756
# 50 4.437095e-01 Type 1 diabetes 6.442986e-03   0.577092888
# 51 1.234281e-02 Type 1 diabetes 3.166332e-06   0.007851037
# 52 1.186910e-02 Type 1 diabetes 3.166332e-06   0.007851037
# 53 4.024053e-04 Type 1 diabetes 3.166332e-06   0.007851037
# 54 1.203403e-01 Type 1 diabetes 3.166332e-06   0.007851037
# 55 3.343557e-01 Type 1 diabetes 3.936295e-03   0.492052254
# 56 4.869803e-01 Type 1 diabetes 3.936295e-03   0.492052254
# 57 4.475788e-01 Type 1 diabetes 3.936295e-03   0.492052254
# [1] 57  7

# %%
wider <- phe_T1D_LVs_nom_0.01[,! colnames(phe_T1D_LVs_nom_0.01) == "phenotype_desc"]%>%
  pivot_wider(
    names_from =phenotype,
      names_sep = "_",
      values_from = c('pvalue','fdr'),
  )

top_17_LV <- inner_join(wider,e_T1D_LVs_nom_0.01, by = "lv")
neg_log10 <- function(x, na.rm = FALSE) -1*log10(x)
top_17_LV_log <- top_17_LV %>% mutate_if(is.double,neg_log10)
top_17_LV_log
# Out:
#    lv    pvalue_E4_DM1KETO pvalue_E4_DM1 pvalue_20002_1222 pvalue_E4_DM1NOCOMP
# 1  LV844 7.648635          5.235228      8.030661          6.463645
# 2  LV913 5.140534          5.163070      6.970883                NA
# 3  LV205 4.480412          3.907064      3.361844          2.158919
# 4  LV71  4.228037          2.659409      2.221348                NA
# 5  LV45  4.060992          4.723757      5.911522          4.819164
# 6  LV342 3.625008          3.469270      2.953793                NA
# 7  LV572 3.109229                NA      2.135340                NA
# 8  LV293 2.958440          4.467884      3.452123          4.112250
# 9  LV987 2.829523          2.373477      2.484882                NA
# 10 LV109 2.827262          3.056672      3.446532                NA
# 11 LV906 2.495888                NA            NA                NA
# 12 LV54  2.297240          2.946872      2.748742                NA
# 13 LV625 2.048809          3.181488      3.172721                NA
# 14 LV187       NA          3.301641      3.782502                NA
# 15 LV52        NA          2.817256      2.659111          3.167733
# 16 LV861       NA          2.722347      3.494835          2.668178
# 17 LV835       NA          2.281108            NA          2.374674
#    pvalue_E4_DM1OPTH fdr_E4_DM1KETO fdr_E4_DM1 fdr_20002_1222 fdr_E4_DM1NOCOMP
# 1        NA          3.9869709      1.9810706  4.3274372      2.9770838
# 2  3.710025          1.9085861      1.9255823  3.3953363             NA
# 3  2.167707          1.4206848      1.0423055  0.7228706      0.2447110
# 4  2.058298          1.2461723      0.4119007  0.2633827             NA
# 5  2.688334          1.1378007      1.5978917  2.5159615      1.6660294
# 6        NA          0.8701195      0.7814160  0.5263253             NA
# 7        NA          0.5973443             NA  0.2372319             NA
# 8  2.855402          0.5282160      1.4115989  0.7711601      1.1705542
# 9        NA          0.4757913      0.3124886  0.3491304             NA
# 10       NA          0.4751797      0.5712306  0.7684678             NA
# 11       NA          0.3529012             NA         NA             NA
# 12       NA          0.2880420      0.5236464  0.4458566             NA
# 13       NA          0.2125518      0.6311101  0.6269765             NA
# 14 2.153654                 NA      0.6898995  0.9609703             NA
# 15 2.382450                 NA      0.4706101  0.4117556      0.6241219
# 16       NA                 NA      0.4357617  0.7964755      0.4157521
# 17       NA                 NA      0.2827378         NA      0.3128309
#    fdr_E4_DM1OPTH phenotype phenotype_desc  pvalue   fdr
# 1         NA      EUR_250.1 Type 1 diabetes 2.834984 0.4482367
# 2  0.9195887      EUR_250.1 Type 1 diabetes 5.499443 2.1050730
# 3  0.2476968      EUR_250.1 Type 1 diabetes 3.026711 0.5292074
# 4  0.2154058      EUR_250.1 Type 1 diabetes 4.068473 1.0733804
# 5  0.4230306      EUR_250.1 Type 1 diabetes 3.529428 0.7831392
# 6         NA      EUR_250.1 Type 1 diabetes 4.384285 1.2802206
# 7         NA      EUR_250.1 Type 1 diabetes 2.201776 0.2428041
# 8  0.4861595      EUR_250.1 Type 1 diabetes 3.852111 0.9406601
# 9         NA      EUR_250.1 Type 1 diabetes 2.404912 0.3079888
# 10        NA      EUR_250.1 Type 1 diabetes 2.182243 0.2362848
# 11        NA      EUR_250.1 Type 1 diabetes 2.190913 0.2387543
# 12        NA      EUR_250.1 Type 1 diabetes 5.917246 2.4106942
# 13        NA      EUR_250.1 Type 1 diabetes 2.020488 0.1952513
# 14 0.2428093      EUR_250.1 Type 1 diabetes 3.279640 0.6460106
# 15 0.3153008      EUR_250.1 Type 1 diabetes 3.844354 0.9406601
# 16        NA      EUR_250.1 Type 1 diabetes 3.395912 0.7075163
# 17        NA      EUR_250.1 Type 1 diabetes 3.076639 0.5523581

# %% [markdown]
# ### UK Biobank Phenotype code description

# %%
pheno_descr_code <- phe_T1D_LVs_nom_0.01 [,c('phenotype','phenotype_desc')]%>%
distinct()

pheno_descr_code
# Out:
#         phenotype    phenotype_desc
# 143115  E4_DM1KETO   Type 1 diabetes with ketoacidosis
# 1619667 E4_DM1       Type 1 diabetes
# 2975805 20002_1222   Non-cancer illness code, self-reported: type 1 diabetes
# 3124842 E4_DM1NOCOMP Type 1 diabetes without complications
# 3214659 E4_DM1OPTH   Type 1 diabetes with ophthalmic complications

# %% [markdown]
# ### Anova between three T1D progression groups using 17 LVs

# %%
T1D_LV <- unique(top_17_LV$lv)
# save for use in python
write_json(as.list(T1D_LV), "T1D_17_LV.json")

# %%
# compute anova for 17 LV
res <- data.frame(matrix(nrow = 0, ncol = 6))
# compare between three groups using anova
for (i in 1:length(T1D_LV)){
    comp_i <- compare_means(as.formula(paste0(T1D_LV[i]," ~ Group")),  data = DAISY_diff_proj,
                            method = "anova")
    res <- rbind(res, comp_i)
    }
res_formated <- res[,c(1,2)]
colnames(res_formated) <- c("LV","DAISY_anova_p.val")
res_formated$DAISY_anova_fdr <- p.adjust(res_formated$DAISY_anova_p.val, method = "BH")
res_formated

#saveRDS(res_formated,paste0("output/anova_",tp,".rds"))
# Out:
#    LV    DAISY_anova_p.val DAISY_anova_fdr
# 1  LV844 0.33049701        0.6420111
# 2  LV913 0.43364680        0.7371996
# 3  LV205 0.03589030        0.2778209
# 4  LV71  0.33988821        0.6420111
# 5  LV45  0.07076396        0.2778209
# 6  LV342 0.08171204        0.2778209
# 7  LV572 0.53353374        0.7558395
# 8  LV293 0.70657858        0.8067499
# 9  LV987 0.48428721        0.7484439
# 10 LV109 0.03206789        0.2778209
# 11 LV906 0.62488447        0.8067499
# 12 LV54  0.71183818        0.8067499
# 13 LV625 0.10182747        0.2885112
# 14 LV187 0.85296831        0.8829169
# 15 LV52  0.88291686        0.8829169
# 16 LV861 0.07247473        0.2778209
# 17 LV835 0.27780265        0.6420111

# %%
analysis_1_df <- inner_join(grouped, res_formated)
dim(analysis_1_df)
analysis_1_df
# Out:
# Joining with `by = join_by(LV)`
# [1] 57  9
#    LV    UK-Bio-Pheno                                            UK-Bio-p-value
# 1  LV109 Type 1 diabetes with ketoacidosis                       1.488463e-03
# 2  LV109 Type 1 diabetes                                         8.776640e-04
# 3  LV109 Non-cancer illness code, self-reported: type 1 diabetes 3.576582e-04
# 4  LV187 Type 1 diabetes                                         4.992971e-04
# 5  LV187 Non-cancer illness code, self-reported: type 1 diabetes 1.650055e-04
# 6  LV187 Type 1 diabetes with ophthalmic complications           7.020139e-03
# 7  LV205 Type 1 diabetes with ketoacidosis                       3.308170e-05
# 8  LV205 Type 1 diabetes                                         1.238614e-04
# 9  LV205 Non-cancer illness code, self-reported: type 1 diabetes 4.346665e-04
# 10 LV205 Type 1 diabetes without complications                   6.935551e-03
# 11 LV205 Type 1 diabetes with ophthalmic complications           6.796624e-03
# 12 LV293 Type 1 diabetes with ketoacidosis                       1.100424e-03
# 13 LV293 Type 1 diabetes                                         3.404989e-05
# 14 LV293 Non-cancer illness code, self-reported: type 1 diabetes 3.530829e-04
# 15 LV293 Type 1 diabetes without complications                   7.722357e-05
# 16 LV293 Type 1 diabetes with ophthalmic complications           1.395077e-03
# 17 LV342 Type 1 diabetes with ketoacidosis                       2.371331e-04
# 18 LV342 Type 1 diabetes                                         3.394141e-04
# 19 LV342 Non-cancer illness code, self-reported: type 1 diabetes 1.112260e-03
# 20 LV45  Type 1 diabetes with ketoacidosis                       8.689770e-05
# 21 LV45  Type 1 diabetes                                         1.889049e-05
# 22 LV45  Non-cancer illness code, self-reported: type 1 diabetes 1.225965e-06
# 23 LV45  Type 1 diabetes without complications                   1.516479e-05
# 24 LV45  Type 1 diabetes with ophthalmic complications           2.049586e-03
# 25 LV52  Type 1 diabetes                                         1.523154e-03
# 26 LV52  Non-cancer illness code, self-reported: type 1 diabetes 2.192244e-03
# 27 LV52  Type 1 diabetes without complications                   6.796215e-04
# 28 LV52  Type 1 diabetes with ophthalmic complications           4.145247e-03
# 29 LV54  Type 1 diabetes with ketoacidosis                       5.043826e-03
# 30 LV54  Type 1 diabetes                                         1.130128e-03
# 31 LV54  Non-cancer illness code, self-reported: type 1 diabetes 1.783437e-03
# 32 LV572 Type 1 diabetes with ketoacidosis                       7.776255e-04
# 33 LV572 Non-cancer illness code, self-reported: type 1 diabetes 7.322507e-03
# 34 LV625 Type 1 diabetes with ketoacidosis                       8.936994e-03
# 35 LV625 Type 1 diabetes                                         6.584334e-04
# 36 LV625 Non-cancer illness code, self-reported: type 1 diabetes 6.718596e-04
# 37 LV71  Type 1 diabetes with ketoacidosis                       5.915115e-05
# 38 LV71  Type 1 diabetes                                         2.190743e-03
# 39 LV71  Non-cancer illness code, self-reported: type 1 diabetes 6.006925e-03
# 40 LV71  Type 1 diabetes with ophthalmic complications           8.743835e-03
# 41 LV835 Type 1 diabetes                                         5.234704e-03
# 42 LV835 Type 1 diabetes without complications                   4.220133e-03
# 43 LV844 Type 1 diabetes with ketoacidosis                       2.245769e-08
# 44 LV844 Type 1 diabetes                                         5.817979e-06
# 45 LV844 Non-cancer illness code, self-reported: type 1 diabetes 9.318352e-09
# 46 LV844 Type 1 diabetes without complications                   3.438391e-07
# 47 LV861 Type 1 diabetes                                         1.895193e-03
# 48 LV861 Non-cancer illness code, self-reported: type 1 diabetes 3.200113e-04
# 49 LV861 Type 1 diabetes without complications                   2.146948e-03
# 50 LV906 Type 1 diabetes with ketoacidosis                       3.192363e-03
# 51 LV913 Type 1 diabetes with ketoacidosis                       7.235450e-06
# 52 LV913 Type 1 diabetes                                         6.869573e-06
# 53 LV913 Non-cancer illness code, self-reported: type 1 diabetes 1.069342e-07
# 54 LV913 Type 1 diabetes with ophthalmic complications           1.949733e-04
# 55 LV987 Type 1 diabetes with ketoacidosis                       1.480734e-03
# 56 LV987 Type 1 diabetes                                         4.231783e-03
# 57 LV987 Non-cancer illness code, self-reported: type 1 diabetes 3.274295e-03
#    UK_Bio_fdr   emerge-pheno    emerge-p-value emerge-fdr  DAISY_anova_p.val
# 1  3.348269e-01 Type 1 diabetes 6.572904e-03   0.580383656 0.03206789
# 2  2.683919e-01 Type 1 diabetes 6.572904e-03   0.580383656 0.03206789
# 3  1.704246e-01 Type 1 diabetes 6.572904e-03   0.580383656 0.03206789
# 4  2.042211e-01 Type 1 diabetes 5.252427e-04   0.225938067 0.85296831
# 5  1.094031e-01 Type 1 diabetes 5.252427e-04   0.225938067 0.85296831
# 6  5.717296e-01 Type 1 diabetes 5.252427e-04   0.225938067 0.85296831
# 7  3.795903e-02 Type 1 diabetes 9.403482e-04   0.295660009 0.03589030
# 8  9.071821e-02 Type 1 diabetes 9.403482e-04   0.295660009 0.03589030
# 46 1.054183e-03 Type 1 diabetes 1.462231e-03   0.356256946 0.33049701
# 47 3.666387e-01 Type 1 diabetes 4.018723e-04   0.196102756 0.07247473
# 48 1.597808e-01 Type 1 diabetes 4.018723e-04   0.196102756 0.07247473
# 49 3.839263e-01 Type 1 diabetes 4.018723e-04   0.196102756 0.07247473
# 50 4.437095e-01 Type 1 diabetes 6.442986e-03   0.577092888 0.62488447
# 51 1.234281e-02 Type 1 diabetes 3.166332e-06   0.007851037 0.43364680
# 52 1.186910e-02 Type 1 diabetes 3.166332e-06   0.007851037 0.43364680
# 53 4.024053e-04 Type 1 diabetes 3.166332e-06   0.007851037 0.43364680
# 54 1.203403e-01 Type 1 diabetes 3.166332e-06   0.007851037 0.43364680
# 55 3.343557e-01 Type 1 diabetes 3.936295e-03   0.492052254 0.48428721
# 56 4.869803e-01 Type 1 diabetes 3.936295e-03   0.492052254 0.48428721
# 57 4.475788e-01 Type 1 diabetes 3.936295e-03   0.492052254 0.48428721
#    DAISY_anova_fdr
# 1  0.2778209
# 2  0.2778209
# 3  0.2778209
# 4  0.8829169
# 5  0.8829169
# 6  0.8829169
# 7  0.2778209
# 8  0.2778209
# 9  0.2778209
# 10 0.2778209
# 11 0.2778209
# 12 0.8067499
# 13 0.8067499
# 14 0.8067499
# 15 0.8067499
# 16 0.8067499
# 17 0.2778209
# 18 0.2778209
# 19 0.2778209
# 20 0.2778209
# 21 0.2778209
# 22 0.2778209
# 23 0.2778209
# 24 0.2778209
# 25 0.8829169
# 26 0.8829169
# 27 0.8829169
# 28 0.8829169
# 29 0.8067499
# 30 0.8067499
# 31 0.8067499
# 32 0.7558395
# 33 0.7558395
# 34 0.2885112
# 35 0.2885112
# 36 0.2885112
# 37 0.6420111
# 38 0.6420111
# 39 0.6420111
# 40 0.6420111
# 41 0.6420111
# 42 0.6420111
# 43 0.6420111
# 44 0.6420111
# 45 0.6420111
# 46 0.6420111
# 47 0.2778209
# 48 0.2778209
# 49 0.2778209
# 50 0.8067499
# 51 0.7371996
# 52 0.7371996
# 53 0.7371996
# 54 0.7371996
# 55 0.7484439
# 56 0.7484439
# 57 0.7484439

# %% [markdown]
# ### Saving output as RDS and CSV

# %%
#saveRDS(analysis_1_df,paste0("output/Analysis_1_Top_17_LVs.rds"))
#write_csv(analysis_1_df,paste0("output/Analysis_1_Top_17_LVs.csv"))

# %% [markdown]
# ### Boxplot of comparison of three groups accross each of 17 LVs

# %%
for (i in 1:length(T1D_LV)){
    plot_i <- ggboxplot(DAISY_diff_proj, x = "Group", y = T1D_LV[i], color = "Group", 
          add = "jitter", legend = "none") +
  rotate_x_text(angle = 45)+
  geom_hline(yintercept = mean(DAISY_diff_proj[,T1D_LV[i]]), linetype = 2)+ # Add horizontal line at base mean
  stat_compare_means(method = "anova", label.y = max(DAISY_diff_proj[,T1D_LV[i]])+ 0.01)       # Add global annova p-value 
    print(plot_i)
    
    #ggsave(paste0("LV_",T1D_LV[i],"_visit_",tp,".png"),path = paste0("figures/visit_",tp))
    } 
    #dev.off()
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
