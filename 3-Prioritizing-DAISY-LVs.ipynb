# %% [markdown]
# # Analysis 1
#
# - *Isolate 17 LVs associate to T1D related traits*
# - What are these LVs telling us
# - *Look at 17 LVs are expressed in RNAseq from Whole blood*
# - Compute 17 daisy anova using LVs from UKbiobank and emerge
# - What are these LVs telling us in three group
# - Look at signatures from the three groups within LVs of interest
# - look at the boxplot for top 17 LVs (UK biobank)

# %% [markdown]
# ## load packages

# %%
library(tidyverse, warn.conflicts=FALSE)
library("ggpubr")
library(reticulate)
library(jsonlite)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘jsonlite’
#
#
# The following object is masked from ‘package:purrr’:
#
#     flatten

# %% [markdown]
# ## Prioritizing LVs differentially expressed accross IA progression status

# %% [markdown]
# ### choose time point

# %%
#tp <- "1"
#tp <- "2" 
tp <- "diff"

# %% [markdown]
# ### Importing RNAseq data

# %%
DAISY_diff_proj <- readRDS(paste0("output/gp_RNA_proj_",tp,".rds"))
LV_names <- colnames(DAISY_diff_proj)[2:988]
length(LV_names)
# Out:
# [1] 987

# %% [markdown]
# ### Anova between three IA progression groups using all LVs

# %%
res <- data.frame(matrix(nrow = 0, ncol = 6))
# compare between three groups using anova
for (i in 1:length(LV_names)){
    comp_i <- compare_means(as.formula(paste0(LV_names[i]," ~ Group")),  data = DAISY_diff_proj,
                            method = "anova")
    res <- rbind(res, comp_i)
    }
res_formated <- res[,c(1,2)]
colnames(res_formated) <- c("LV","DAISY_anova_p.val")
res_formated$DAISY_anova_fdr <- p.adjust(res_formated$DAISY_anova_p.val, method = "BH")
#res_formated

#saveRDS(res_formated,paste0("output/anova_4-LV_",tp,".rds"))

# %%
sig_LV <- res_formated[res_formated$DAISY_anova_p.val<0.005,]
LV_sig_names <- sig_LV$LV
#hist(res_formated$DAISY_anova_p.val)

# %%
# Import data
gls_phenomexcan <- readRDS("data/input/gls-summary-phenomexcan.rds")
gls_emerge <- readRDS("data/input/gls-summary-emerge.rds")

# %%
DAISY_gls_traits <- gls_phenomexcan[gls_phenomexcan$lv == "LV908",]
length(unique(DAISY_gls_traits$lv))
length(unique(DAISY_gls_traits$phenotype_desc))
DAISY_gls_traits$ranking <- rank(DAISY_gls_traits$pvalue, ties.method = "average")

DAISY_gls_traits%>%
arrange(ranking)
head(DAISY_gls_traits,5)
# Out:
# [1] 1
# [1] 4091
#         phenotype
# 1214999 2395_3
# 2364857 3581_raw
# 506331  20118_13
# 2589892 20090_373
# 1512084 20002_1435
# 2419153 2395_1
# 3550243 1508_2
# 3007392 M13_BURSOPATHY
# 2688588 22606_2
# 210232  20111_101
# 3253156 20002_1288
# 3961819 K02
# 1616707 M13_ARTHRITISNAS
# 3858186 5843_1
# 3034040 22601_21313058
# 2532645 20002_1290
# 1039314 100010
# 2113174 6147_1
# 1001811 1309
# 2907706 20003_1140882272
# 607993  20001_1060
# 3965774 20111_5
# 2192130 22617_5312
# 2474415 M13_ENTESOPATHYNAS
# 2827759 24005_raw
# 2202994 I9_DVTANDPULM
# 2246421 100003_raw
# 1973016 20002_1657
# 3513732 100920_2103
# 1659152 22643_raw
# ⋮       ⋮
# 1710465 20118_16
# 2371750 H7_PTOSIS
# 3839424 20024_2211
# 706683  20090_365
# 2782346 20003_1140888098
# 1419299 M13_OTHCONN
# 931722  C32
# 3239326 E4_THYTOXNAS
# 2219757 G40
# 3013298 M65
# 3819685 20090_355
# 2933360 20090_379
# 2416173 M13_DEQUERVAIN
# 1409430 22601_71113328
# 3412055 22617_7111
# 3505820 D70
# 2268122 20003_1140910832
# 2682657 20002_1479
# 2659960 40009
# 552717  6156_15
# 2457625 PNEUMOBACTKNOWN
# 2396433 22601_72123325
# 1553533 22601_31113033
# 751102  E22
# 1589066 20003_2038459704
# 3225515 OTHER_SYSTCON_FG
# 87842   20003_1141145638
# 2472434 G6_DISBROTHUNS
# 1006737 20553_3
# 2802091 5832_1
#         phenotype_desc
# 1214999 Hair/balding pattern: Pattern 3
# 2364857 Age at menopause (last menstrual period)
# 506331  Home area population density - urban or rural: Scotland - Accessible Small Town
# 2589892 Type of fat/oil used in cooking: Low fat polyunsaturated margarine
# 1512084 Non-cancer illness code, self-reported: optic neuritis
# 2419153 Hair/balding pattern: Pattern 1
# 3550243 Coffee type: Instant coffee
# 3007392 Other bursopathies
# 2688588 Workplace very noisy: Often
# 210232  Illnesses of siblings: None of the above (group 2)
# 3253156 Non-cancer illness code, self-reported: nervous breakdown
# 3961819 Diagnoses - main ICD10: K02 Dental caries
# 1616707 Ohter specific/unspecified arthritis
# 3858186 Which eye(s) affected by myopia (short sight): Right eye
# 3034040 Job coding: it strategy or planning professional, computer consultant, software consultant (22601_21313058)
# 2532645 Non-cancer illness code, self-reported: deliberate self-harm/suicide attempt
# 1039314 Portion size
# 2113174 Reason for glasses/contact lenses: For short-sightedness, i.e. only or mainly for distance viewing such as driving, cinema etc (called 'myopia')
# 1001811 Fresh fruit intake
# 2907706 Treatment/medication code: oramorph 10mg/5ml oral solution (20003_1140882272)
# 607993  Cancer code, self-reported: non-melanoma skin cancer
# 3965774 Illnesses of siblings: Breast cancer
# 2192130 Job SOC coding: Bricklayers, masons
# 2474415 Other/unspecified enthesopathies, not elsewhere classified
# 2827759 Particulate matter air pollution (pm10); 2010
# 2202994 DVT of lower extremities and pulmonary embolism
# 2246421 Protein
# 1973016 Non-cancer illness code, self-reported: septicaemia / sepsis
# 3513732 Type milk consumed: skimmed
# 1659152 Number of night shifts worked monthly during mixed shift periods
# ⋮       ⋮
# 1710465 Home area population density - urban or rural: Scotland - Accessible Rural
# 2371750 Ptosis of eyelid
# 3839424 Job code - deduced: Medical practitioners
# 706683  Type of fat/oil used in cooking: Olive spread
# 2782346 Treatment/medication code: fluticasone (20003_1140888098)
# 1419299 #Other systemic involvement of connective tissue
# 931722  Diagnoses - main ICD10: C32 Malignant neoplasm of larynx
# 3239326 Thyrotoxicosis, other and/or unspecified
# 2219757 Diagnoses - main ICD10: G40 Epilepsy
# 3013298 Diagnoses - main ICD10: M65 Synovitis and tenosynovitis
# 3819685 Type of fat/oil used in cooking: Vegetable oil
# 2933360 Type of fat/oil used in cooking: Low fat dairy spread
# 2416173 Radial styloid tenosynovitis [de Quervain]
# 1409430 Job coding: sales assistant, retail/shop assistant, counter assistant, sub post office assistant, takeaway food worker (22601_71113328)
# 3412055 Job SOC coding: Sales and retail assistants
# 3505820 Diagnoses - main ICD10: D70 Agranulocytosis
# 2268122 Treatment/medication code: sodium warfarin (20003_1140910832)
# 2682657 Non-cancer illness code, self-reported: rheumatic fever
# 2659960 Reported occurrences of cancer
# 552717  Manic/hyper symptoms: All of the above
# 2457625 Bacterial pneumonia (organism specified)
# 2396433 Job coding: customer care adviser/officer/assistant, store guide, customer relations officer/representative (22601_72123325)
# 1553533 Job coding: laboratory technician, scientific assistant, cytology screener; hospital, medical or health technician (22601_31113033)
# 751102  Diagnoses - main ICD10: E22 Hyperfunction of pituitary gland
# 1589066 Treatment/medication code: carbamazepine (20003_2038459704)
# 3225515 Other systemic involvement of connective tissue (FG)
# 87842   Treatment/medication code: nasobec aqueous 50micrograms nasal spray (20003_1141145638)
# 2472434 Disorders of brain, other and unspecified
# 1006737 Methods of self-harm used: Stopping prescribed medication
# 2802091 Which eye(s) affected by hypermetropia (long sight): Right eye
#         lv    pvalue       fdr         ranking
# 1214999 LV908 4.768473e-07 0.001393214  1
# 2364857 LV908 3.001605e-06 0.006240953  2
# 506331  LV908 6.649201e-05 0.061018767  3
# 2589892 LV908 2.192486e-04 0.128937611  4
# 1512084 LV908 4.821181e-04 0.200567148  5
# 2419153 LV908 5.621297e-04 0.216499109  6
# 3550243 LV908 5.689271e-04 0.217910636  7
# 3007392 LV908 6.015820e-04 0.223696317  8
# 2688588 LV908 6.493420e-04 0.232460683  9
# 210232  LV908 7.264051e-04 0.244640637 10
# 3253156 LV908 8.157058e-04 0.258814292 11
# 3961819 LV908 8.473662e-04 0.263410856 12
# 1616707 LV908 1.107811e-03 0.297159235 13
# 3858186 LV908 1.114633e-03 0.297953820 14
# 3034040 LV908 1.159140e-03 0.302429281 15
# 2532645 LV908 1.209321e-03 0.308426928 16
# 1039314 LV908 1.350738e-03 0.322157997 17
# 2113174 LV908 1.533395e-03 0.339078126 18
# 1001811 LV908 1.577196e-03 0.342112712 19
# 2907706 LV908 1.687875e-03 0.350687136 20
# 607993  LV908 2.080532e-03 0.379736747 21
# 3965774 LV908 2.415728e-03 0.402245447 22
# 2192130 LV908 2.654961e-03 0.416340467 23
# 2474415 LV908 2.933455e-03 0.431292286 24
# 2827759 LV908 2.988114e-03 0.434298427 25
# 2202994 LV908 3.137897e-03 0.441613141 26
# 2246421 LV908 3.181759e-03 0.442966653 27
# 1973016 LV908 3.244540e-03 0.446081527 28
# 3513732 LV908 3.362722e-03 0.451235926 29
# 1659152 LV908 3.377103e-03 0.451827132 30
# ⋮       ⋮     ⋮            ⋮           ⋮
# 1710465 LV908 0.9864613    0.9932896   4062
# 2371750 LV908 0.9867334    0.9933714   4063
# 3839424 LV908 0.9867573    0.9933803   4064
# 706683  LV908 0.9871184    0.9935055   4065
# 2782346 LV908 0.9876977    0.9937003   4066
# 1419299 LV908 0.9877212    0.9937060   4067
# 931722  LV908 0.9880071    0.9937977   4068
# 3239326 LV908 0.9883720    0.9939147   4069
# 2219757 LV908 0.9887012    0.9940331   4070
# 3013298 LV908 0.9889309    0.9941175   4071
# 3819685 LV908 0.9893849    0.9942557   4072
# 2933360 LV908 0.9896632    0.9943537   4073
# 2416173 LV908 0.9902449    0.9945728   4074
# 1409430 LV908 0.9904322    0.9946397   4075
# 3412055 LV908 0.9904523    0.9946488   4076
# 3505820 LV908 0.9904554    0.9946504   4077
# 2268122 LV908 0.9913745    0.9950304   4078
# 2682657 LV908 0.9915599    0.9951003   4079
# 2659960 LV908 0.9916346    0.9951310   4080
# 552717  LV908 0.9916393    0.9951340   4081
# 2457625 LV908 0.9928266    0.9956338   4082
# 2396433 LV908 0.9929186    0.9956786   4083
# 1553533 LV908 0.9930316    0.9957259   4084
# 751102  LV908 0.9932055    0.9958092   4085
# 1589066 LV908 0.9946316    0.9964699   4086
# 3225515 LV908 0.9948367    0.9965692   4087
# 87842   LV908 0.9948538    0.9965780   4088
# 2472434 LV908 0.9953329    0.9968287   4089
# 1006737 LV908 0.9961020    0.9972581   4090
# 2802091 LV908 0.9993740    0.9994381   4091
#      phenotype
# 652  AB1_OTHER_VIRAL
# 1208 20002_1134
# 2170 1747_4
# 3057 22617_1136
# 4628 M13_SHOULDER
#      phenotype_desc                                                    lv
# 652  Other viral diseases                                              LV908
# 1208 Non-cancer illness code, self-reported: oesophageal disorder      LV908
# 2170 Hair colour (natural, before greying): Dark brown                 LV908
# 3057 Job SOC coding: Information and communication technology managers LV908
# 4628 Shoulder lesions                                                  LV908
#      pvalue    fdr       ranking
# 652  0.6522721 0.9874479 2604
# 1208 0.2169431 0.9874479  821
# 2170 0.3923763 0.9874479 1513
# 3057 0.1029559 0.9874479  411
# 4628 0.6893051 0.9874479 2770

# %%
#DAISY_emerge_traits <- gls_emerge[gls_emerge$lv %in% LV_sig_names & gls_emerge$pvalue < 0.05,]
DAISY_emerge_traits <- gls_emerge[gls_emerge$lv == "LV908",]
length(unique(DAISY_emerge_traits$lv))
length(unique(DAISY_emerge_traits$phenotype_desc))
DAISY_emerge_traits$ranking <- rank(DAISY_emerge_traits$pvalue, ties.method = "average")

DAISY_emerge_traits%>%
arrange(ranking)
head(DAISY_emerge_traits,5)
# Out:
# [1] 1
# [1] 309
#        phenotype
# 100675 EUR_112
# 96728  EUR_594.1
# 205300 EUR_594
# 54303  EUR_426.2
# 162879 EUR_250.41
# 261578 EUR_427
# 143146 EUR_426.24
# 224063 EUR_080
# 53333  EUR_743.1
# 68140  EUR_380.4
# 291210 EUR_743
# 10871  EUR_286
# 140207 EUR_426
# 242853 EUR_426.21
# 239911 EUR_427.6
# 231019 EUR_038
# 217236 EUR_743.9
# 232993 EUR_401.2
# 59302  EUR_366.2
# 87909  EUR_427.5
# 2048   EUR_706
# 202439 EUR_079
# 92840  EUR_272.11
# 88940  EUR_366
# 77098  EUR_365
# 27743  EUR_426.31
# 289307 EUR_374
# 148164 EUR_593
# 32657  EUR_415.1
# 119536 EUR_327.3
# ⋮      ⋮
# 238779 EUR_249
# 155864 EUR_519
# 259525 EUR_244.2
# 181569 EUR_261
# 217089 EUR_276.41
# 111481 EUR_428.4
# 265465 EUR_473.4
# 19701  EUR_440.22
# 170703 EUR_585
# 288176 EUR_507
# 191443 EUR_270
# 151964 EUR_280
# 73008  EUR_573.6
# 161850 EUR_564
# 20704  EUR_433.6
# 94726  EUR_443
# 189480 EUR_599.3
# 14785  EUR_573
# 102618 EUR_585.1
# 209227 EUR_433.31
# 269427 EUR_585.3
# 287203 EUR_443.9
# 200347 EUR_440
# 124339 EUR_473
# 81907  EUR_280.1
# 201335 EUR_292.4
# 982    EUR_440.2
# 58218  EUR_588
# 284252 EUR_433.3
# 48351  EUR_585.2
#        phenotype_desc
# 100675 Candidiasis
# 96728  Calculus of kidney
# 205300 Urinary calculus
# 54303  Atrioventricular [AV] block
# 162879 Impaired fasting glucose
# 261578 Cardiac dysrhythmias
# 143146 Atrioventricular block, complete
# 224063 Postoperative infection
# 53333  Osteoporosis
# 68140  Impacted cerumen
# 291210 Osteoporosis, osteopenia and pathological fracture
# 10871  Coagulation defects
# 140207 Cardiac conduction disorders
# 242853 First degree AV block
# 239911 Premature beats
# 231019 Septicemia
# 217236 Osteopenia or other disorder of bone and cartilage
# 232993 Hypertensive heart and/or renal disease
# 59302  Senile cataract
# 87909  Arrhythmia (cardiac) NOS
# 2048   Diseases of sebaceous glands
# 202439 Viral infection
# 92840  Hypercholesterolemia
# 88940  Cataract
# 77098  Glaucoma
# 27743  Right bundle branch block
# 289307 Other disorders of eyelids
# 148164 Hematuria
# 32657  Acute pulmonary heart disease
# 119536 Sleep apnea
# ⋮      ⋮
# 238779 Secondary diabetes mellitus
# 155864 Other diseases of respiratory system, not elsewhere classified
# 259525 Acquired hypothyroidism
# 181569 Vitamin deficiency
# 217089 Acidosis
# 111481 Heart failure with preserved EF [Diastolic heart failure]
# 265465 Voice disturbance
# 19701  Atherosclerosis of native arteries of the extremities with intermittent claudication
# 170703 Renal failure
# 288176 Pleurisy; pleural effusion
# 191443 Disorders of protein plasma/amino-acid transport and metabolism
# 151964 Iron deficiency anemias
# 73008  Nonspecific elevation of levels of transaminase or lactic acid dehydrogenase [LDH]
# 161850 Functional digestive disorders
# 20704  Acute, but ill-defined cerebrovascular disease
# 94726  Peripheral vascular disease
# 189480 Dysuria
# 14785  Other disorders of liver
# 102618 Acute renal failure
# 209227 Transient cerebral ischemia
# 269427 Chronic renal failure [CKD]
# 287203 Peripheral vascular disease, unspecified
# 200347 Atherosclerosis
# 124339 Diseases of the larynx and vocal cords
# 81907  Iron deficiency anemias, unspecified or not due to blood loss
# 201335 Altered mental status
# 982    Atherosclerosis of the extremities
# 58218  Disorders resulting from impaired renal function
# 284252 Cerebral ischemia
# 48351  Renal failure NOS
#        lv    pvalue       fdr       ranking
# 100675 LV908 0.0001864605 0.1310406  1
# 96728  LV908 0.0003866026 0.1914078  2
# 205300 LV908 0.0022789108 0.4128075  3
# 54303  LV908 0.0114965478 0.6665473  4
# 162879 LV908 0.0173906818 0.7241275  5
# 261578 LV908 0.0176878937 0.7276109  6
# 143146 LV908 0.0200383305 0.7489510  7
# 224063 LV908 0.0218769014 0.7624678  8
# 53333  LV908 0.0283184436 0.8063436  9
# 68140  LV908 0.0295712802 0.8150759 10
# 291210 LV908 0.0304073420 0.8197055 11
# 10871  LV908 0.0342016191 0.8368215 12
# 140207 LV908 0.0354754910 0.8430628 13
# 242853 LV908 0.0421341996 0.8692488 14
# 239911 LV908 0.0649171119 0.9280405 15
# 231019 LV908 0.0660120070 0.9301973 16
# 217236 LV908 0.0690502466 0.9372440 17
# 232993 LV908 0.0694238562 0.9379037 18
# 59302  LV908 0.0697322565 0.9384473 19
# 87909  LV908 0.0767723278 0.9525976 20
# 2048   LV908 0.0793635388 0.9563228 21
# 202439 LV908 0.0812715479 0.9607336 22
# 92840  LV908 0.0847556353 0.9658889 23
# 88940  LV908 0.0901340352 0.9746044 24
# 77098  LV908 0.0955198594 0.9823498 25
# 27743  LV908 0.0979929979 0.9845753 26
# 289307 LV908 0.1125327419 0.9874661 27
# 148164 LV908 0.1142376396 0.9874661 28
# 32657  LV908 0.1177177893 0.9874661 29
# 119536 LV908 0.1198962521 0.9874661 30
# ⋮      ⋮     ⋮            ⋮         ⋮
# 238779 LV908 0.9256498    0.9874661 280
# 155864 LV908 0.9318164    0.9874661 281
# 259525 LV908 0.9323333    0.9874661 282
# 181569 LV908 0.9375853    0.9877380 283
# 217089 LV908 0.9386470    0.9877380 284
# 111481 LV908 0.9398768    0.9877380 285
# 265465 LV908 0.9423318    0.9877380 286
# 19701  LV908 0.9425047    0.9877380 287
# 170703 LV908 0.9484869    0.9879901 288
# 288176 LV908 0.9488764    0.9880468 289
# 191443 LV908 0.9536833    0.9882903 290
# 151964 LV908 0.9584734    0.9885876 291
# 73008  LV908 0.9596214    0.9886890 292
# 161850 LV908 0.9602300    0.9886929 293
# 20704  LV908 0.9616244    0.9888401 294
# 94726  LV908 0.9621780    0.9889072 295
# 189480 LV908 0.9673473    0.9895867 296
# 14785  LV908 0.9677953    0.9896081 297
# 102618 LV908 0.9684516    0.9896395 298
# 209227 LV908 0.9689979    0.9897365 299
# 269427 LV908 0.9697533    0.9898300 300
# 287203 LV908 0.9703795    0.9898851 301
# 200347 LV908 0.9714762    0.9901077 302
# 124339 LV908 0.9722286    0.9901408 303
# 81907  LV908 0.9724261    0.9901550 304
# 201335 LV908 0.9735909    0.9902854 305
# 982    LV908 0.9834551    0.9926532 306
# 58218  LV908 0.9875839    0.9937850 307
# 284252 LV908 0.9912099    0.9949182 308
# 48351  LV908 0.9914100    0.9949627 309
#      phenotype  phenotype_desc                                      lv
# 982  EUR_440.2  Atherosclerosis of the extremities                  LV908
# 1683 EUR_433.21 Cerebral artery occlusion, with cerebral infarction LV908
# 2048 EUR_706    Diseases of sebaceous glands                        LV908
# 3801 EUR_740.1  Osteoarthritis; localized                           LV908
# 4631 EUR_250.24 Type 2 diabetes with neurological manifestations    LV908
#      pvalue     fdr       ranking
# 982  0.98345514 0.9926532 306
# 1683 0.70914537 0.9874661 195
# 2048 0.07936354 0.9563228  21
# 3801 0.85081816 0.9874661 250
# 4631 0.70195061 0.9874661 192

# %% [markdown]
# ### Box plot for LVs

# %%
for (i in 1:length(LV_sig_names)){
    plot_i <- ggboxplot(DAISY_diff_proj, x = "Group", y = LV_sig_names[i], color = "Group", 
          add = "jitter", legend = "none") +
  rotate_x_text(angle = 45)+
  geom_hline(yintercept = mean(DAISY_diff_proj[,LV_sig_names[i]]), linetype = 2)+ # Add horizontal line at base mean
  stat_compare_means(method = "anova", label.y = max(DAISY_diff_proj[,LV_sig_names[i]])+ 0.01)       # Add global annova p-value 
    print(plot_i)
    
    #ggsave(paste0("LV_",T1D_LV[i],"_visit_",tp,".png"),path = paste0("figures/visit_",tp))
    } 
    #dev.off()
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### Importing data: UKBiobank and emerge LV, phenotype traits strings

# %%
# Import data
gls_phenomexcan <- readRDS("data/input/gls-summary-phenomexcan.rds")
gls_emerge <- readRDS("data/input/gls-summary-emerge.rds")

# Type 1 diabetes traits in dataset 
UK_biobank_traits <-  c('Type 1 diabetes with ketoacidosis','Type 1 diabetes', 'Non-cancer illness code, self-reported: type 1 diabetes', 'Type 1 diabetes without complications','Type 1 diabetes with ophthalmic complications')
emerge_trait <- 'Type 1 diabetes'

# setting threshold 
threshold <- 0.05

# %% [markdown]
# ### LVs associated with T1D in phenomexcan and emerge at an FDR adjusted `threshold`

# %%
## Phenomexcan
phe_T1D_LVs <- gls_phenomexcan[gls_phenomexcan$phenotype_desc %in% UK_biobank_traits,]
phe_T1D_LVs$new_fdr_UK <- p.adjust(phe_T1D_LVs$pvalue, method = "BH")
phe_T1D_LVs_0.05_fdr <- phe_T1D_LVs[phe_T1D_LVs$new_fdr_UK < threshold,]

## E-merge
e_T1D_LVs <- gls_emerge[gls_emerge$phenotype_desc %in% emerge_trait,]
e_T1D_LVs$new_fdr_e <- p.adjust(e_T1D_LVs$pvalue, method = "BH")
e_T1D_LVs_0.05_fdr <- e_T1D_LVs[e_T1D_LVs$new_fdr_e < threshold,]

## Joining
phe_U_e_fdr_0.05 <- inner_join(phe_T1D_LVs_0.05_fdr,e_T1D_LVs_0.05_fdr, by = "lv")
merged_cohort_T1D <- phe_U_e_fdr_0.05%>%
arrange(lv)%>%
select(c(3,2,4,6,8,9,11))
colnames(merged_cohort_T1D) <- c("LV","UK-Bio-Pheno", "UK-Bio-p-value","UK_Bio_fdr","emerge-pheno","emerge-p-value","emerge-fdr")
merged_cohort_T1D
# Out:
#    LV    UK-Bio-Pheno                                            UK-Bio-p-value
# 1  LV293 Type 1 diabetes                                         3.404989e-05
# 2  LV293 Type 1 diabetes without complications                   7.722357e-05
# 3  LV45  Type 1 diabetes with ketoacidosis                       8.689770e-05
# 4  LV45  Type 1 diabetes                                         1.889049e-05
# 5  LV45  Non-cancer illness code, self-reported: type 1 diabetes 1.225965e-06
# 6  LV45  Type 1 diabetes without complications                   1.516479e-05
# 7  LV71  Type 1 diabetes with ketoacidosis                       5.915115e-05
# 8  LV913 Type 1 diabetes with ketoacidosis                       7.235450e-06
# 9  LV913 Type 1 diabetes                                         6.869573e-06
# 10 LV913 Non-cancer illness code, self-reported: type 1 diabetes 1.069342e-07
# 11 LV913 Type 1 diabetes with ophthalmic complications           1.949733e-04
#    UK_Bio_fdr   emerge-pheno    emerge-p-value emerge-fdr
# 1  0.0137392187 Type 1 diabetes 1.405687e-04   0.023540275
# 2  0.0254065554 Type 1 diabetes 1.405687e-04   0.023540275
# 3  0.0268025084 Type 1 diabetes 2.955102e-04   0.041666938
# 4  0.0093224579 Type 1 diabetes 2.955102e-04   0.041666938
# 5  0.0012100271 Type 1 diabetes 2.955102e-04   0.041666938
# 6  0.0083153581 Type 1 diabetes 2.955102e-04   0.041666938
# 7  0.0208507802 Type 1 diabetes 8.541361e-05   0.021075809
# 8  0.0044633680 Type 1 diabetes 3.166332e-06   0.001562585
# 9  0.0044633680 Type 1 diabetes 3.166332e-06   0.001562585
# 10 0.0001759068 Type 1 diabetes 3.166332e-06   0.001562585
# 11 0.0458187285 Type 1 diabetes 3.166332e-06   0.001562585

# %%
Analysis_1_df <- inner_join(merged_cohort_T1D, res_formated)
dim(Analysis_1_df)
Analysis_1_df
# Out:
# Joining with `by = join_by(LV)`
# [1] 11  9
#    LV    UK-Bio-Pheno                                            UK-Bio-p-value
# 1  LV293 Type 1 diabetes                                         3.404989e-05
# 2  LV293 Type 1 diabetes without complications                   7.722357e-05
# 3  LV45  Type 1 diabetes with ketoacidosis                       8.689770e-05
# 4  LV45  Type 1 diabetes                                         1.889049e-05
# 5  LV45  Non-cancer illness code, self-reported: type 1 diabetes 1.225965e-06
# 6  LV45  Type 1 diabetes without complications                   1.516479e-05
# 7  LV71  Type 1 diabetes with ketoacidosis                       5.915115e-05
# 8  LV913 Type 1 diabetes with ketoacidosis                       7.235450e-06
# 9  LV913 Type 1 diabetes                                         6.869573e-06
# 10 LV913 Non-cancer illness code, self-reported: type 1 diabetes 1.069342e-07
# 11 LV913 Type 1 diabetes with ophthalmic complications           1.949733e-04
#    UK_Bio_fdr   emerge-pheno    emerge-p-value emerge-fdr  DAISY_anova_p.val
# 1  0.0137392187 Type 1 diabetes 1.405687e-04   0.023540275 0.70657858
# 2  0.0254065554 Type 1 diabetes 1.405687e-04   0.023540275 0.70657858
# 3  0.0268025084 Type 1 diabetes 2.955102e-04   0.041666938 0.07076396
# 4  0.0093224579 Type 1 diabetes 2.955102e-04   0.041666938 0.07076396
# 5  0.0012100271 Type 1 diabetes 2.955102e-04   0.041666938 0.07076396
# 6  0.0083153581 Type 1 diabetes 2.955102e-04   0.041666938 0.07076396
# 7  0.0208507802 Type 1 diabetes 8.541361e-05   0.021075809 0.33988821
# 8  0.0044633680 Type 1 diabetes 3.166332e-06   0.001562585 0.43364680
# 9  0.0044633680 Type 1 diabetes 3.166332e-06   0.001562585 0.43364680
# 10 0.0001759068 Type 1 diabetes 3.166332e-06   0.001562585 0.43364680
# 11 0.0458187285 Type 1 diabetes 3.166332e-06   0.001562585 0.43364680
#    DAISY_anova_fdr
# 1  0.7065786
# 2  0.7065786
# 3  0.2830558
# 4  0.2830558
# 5  0.2830558
# 6  0.2830558
# 7  0.5781957
# 8  0.5781957
# 9  0.5781957
# 10 0.5781957
# 11 0.5781957

# %% [markdown]
# ### Saving output as RDS and CSV

# %%
#saveRDS(analysis_1_df,paste0("output/Analysis_1_Top_17_LVs.rds"))
#write_csv(analysis_1_df,paste0("output/Analysis_1_Top_17_LVs.csv"))

# %% [markdown]
# #### UK Biobank Phenotype code description

# %%
pheno_descr_code <- phe_T1D_LVs_nom_0.01 [,c('phenotype','phenotype_desc')]%>%
distinct()

pheno_descr_code
